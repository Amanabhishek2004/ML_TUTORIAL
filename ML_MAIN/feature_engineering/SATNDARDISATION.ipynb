# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("social_ads.csv")
df = df.drop("Gender" ,axis =1)
df = df.drop("User ID" , axis=1)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
# train test split
x_train,x_test,y_train,y_test = train_test_split(df.drop("Purchased" , axis = 1),df["Purchased"],test_size=0.3 , random_state=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
# means it is calculating the mean of all the numerical columns
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
# these are numpy arrays
x_test_scaled = scaler.transform(x_test)
x_test_scaled.mean
# Out:
# <function ndarray.mean>

# %%
x_train_scaled = pd.DataFrame(x_train_scaled , columns = x_train.columns)

x_train_scaled
x_test_scaled = pd.DataFrame(x_test_scaled , columns = x_test.columns)
x_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
fig , (ax1,ax2)=plt.subplots(ncols = 2 , figsize = (12,5))
ax1.scatter(x_train["Age"] , x_train["EstimatedSalary"])
ax1.set_title("Before Scalling")
ax2.scatter(x_train_scaled["Age"] , x_train_scaled["EstimatedSalary"] ,color = "yellow")
ax2.set_title("After Scalling")
# Out:
# Text(0.5, 1.0, 'After Scalling')

# %%
# plt2 = sns.distplot(x_train["Age"],hist=False)
# plt1 = sns.distplot(x_train["EstimatedSalary"],hist=False , color="red")
# plt1.set_title("before scaling")
plt3 = sns.distplot(x_train_scaled["Age"],hist=False)
plt4 = sns.distplot(x_train_scaled["EstimatedSalary"],hist=False , color="red")
plt4.set_title("after scaling")
plt4
# # plt1
# Out:
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_19024\1356663651.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plt3 = sns.distplot(x_train_scaled["Age"],hist=False)
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_19024\1356663651.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
new_data = pd.DataFrame({
    "Age": [5, 90, 95],
    "EstimatedSalary": [1000, 250000, 350000],
    "Purchased": [0, 1, 1]
})

# Append the new data to the original DataFrame using concat
df = pd.concat([df, new_data], ignore_index=True)
df.tail(3)
# Out:
#      Age  EstimatedSalary  Purchased
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
