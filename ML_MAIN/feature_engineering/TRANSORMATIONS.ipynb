# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv("concrete.csv")
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
x = df.drop(columns=["Strength"])
y = df.iloc[:,-1]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
for i in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[i])
    plt.title(i)

    plt.subplot(122)
    stats.probplot(x_train[i],dist="norm" , plot=plt)
    plt.title(i)

    plt.show()
# Out:
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_29120\1431920049.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[i])
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_29120\1431920049.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[i])
# ...

# %%
# Applying Box-Cox Transform

pt = PowerTransformer(method='box-cox')

X_train_transformed = pt.fit_transform(x_train+0.000001)
X_test_transformed = pt.transform(x_test+0.000001)

ne_df = pd.DataFrame({'cols':x_train.columns,'box_cox_lambdas':pt.lambdas_})
ne_df
# Out:
#                  cols  box_cox_lambdas
# 0              Cement         0.177025
# 1  Blast Furnace Slag         0.025093
# 2             Fly Ash        -0.038970
# 3               Water         0.772682
# 4    Superplasticizer         0.098811
# 5    Coarse Aggregate         1.129813
# 6      Fine Aggregate         1.782019
# 7                 Age         0.066631

# %%
# Applying linear regression on transformed data

lr = LinearRegression()
lr.fit(X_train_transformed,y_train)

y_pred2 = lr.predict(X_test_transformed)

r2_score(y_test,y_pred2)
# Out:
# 0.8047825006181188

# %%
X_train_transformed = pd.DataFrame(X_test_transformed , columns = x_train.columns)

for i in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[i])
    plt.title(i)

    plt.subplot(122)
    sns.distplot(X_train_transformed[i])
    plt.title(i)

    plt.show()
# Out:
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_23548\4247308382.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[i])
# C:\Users\AMAN\AppData\Local\Temp\ipykernel_23548\4247308382.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train_transformed[i])
# ...

# %% [markdown]
# <H2>YEO-JOHNSON
# </H2>

# %%
pt1 = PowerTransformer()
pt1.fit_transform(x_train)
pt1.fit_transform(x_test)


pd.DataFrame({"cols":x_train.columns , "lambda_of_box_cox":pt.lambdas_ , "lmbdas_of_Yeo_Johnson":pt1.lambdas_})
# Out:
#                  cols  lambda_of_box_cox  lmbdas_of_Yeo_Johnson
# 0              Cement           0.177025               0.213025
# 1  Blast Furnace Slag           0.025093               0.020476
# 2             Fly Ash          -0.038970              -0.038218
# 3               Water           0.772682               0.958936
# 4    Superplasticizer           0.098811               0.304951
# 5    Coarse Aggregate           1.129813               1.192751
# 6      Fine Aggregate           1.782019               1.975085
# 7                 Age           0.066631              -0.062443
