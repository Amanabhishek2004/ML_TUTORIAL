# %%
from sklearn.datasets import make_classification
import numpy as np

x , y = make_classification(n_samples=100 , n_features=2 , n_informative=1 , n_redundant=0 , n_classes=2 , n_clusters_per_class=1 , random_state=41)

# %%
x.shape
# Out:
# (100, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[: , 0] , x[:,1] , c=y)

# %%
def predict(x):
 if x>0:
  return 1
 
 else:
  return 0

# %%
def mylositic_regressor(x,y):

        x = np.insert(x,0,1 , axis = 1)
        betas = np.ones(x.shape[1])
        lr = 0.1

        """
        for shifting the line towards a point xis added to the
        betas and vice versa
        """
        for i in range(1000):
           j = np.random.randint(0,99)
           y_pred = predict(np.dot(x[j],betas))
           betas = betas + lr*(y[j]-y_pred)*x[j]

        return betas[0] , betas[1:]

# %%
intercept , slopes = mylositic_regressor(x,y)

# %%
x_input = np.linspace(-3,3,100)

#  plotting the graph 

m = - (slopes[0]/slopes[1])
b = - (intercept/slopes[1])

# %%
plt.figure(figsize=(10,6))
plt.plot(x , m*x+b , color = "red")
plt.scatter(x[: , 0] , x[:,1] , c=y)
